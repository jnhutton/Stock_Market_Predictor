# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosvalenciano/Project4/blob/main/Stock_Market_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yahoo_fin
# Out:
# Requirement already satisfied: yahoo_fin in /usr/local/lib/python3.10/dist-packages (0.8.9.1)
# Requirement already satisfied: requests-html in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (6.0.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (1.5.3)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.10/dist-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (2023.11.17)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.10/dist-packages (from requests-html->yahoo_fin) (2.0.0)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.10/dist-packages (from requests-html->yahoo_fin) (1.4.0)
# Requirement already satisfied: parse in /usr/local/lib/python3.10/dist-packages (from requests-html->yahoo_fin) (1.20.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.10/dist-packages (from requests-html->yahoo_fin) (2.1.2)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.10/dist-packages (from requests-html->yahoo_fin) (1.0.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (7.0.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.66.1)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->yahoo_fin) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->requests-html->yahoo_fin) (4.11.2)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html->yahoo_fin) (4.9.3)
# Requirement already satisfied: cssselect>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html->yahoo_fin) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.5)

# %%
import numpy as np
import time as tm
import datetime as dt
import tensorflow as tf
import pandas as pd

# Data preparation
from yahoo_fin import stock_info as yf
from sklearn.preprocessing import MinMaxScaler
from collections import deque

# AI
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# For time stamps
from datetime import datetime

# Graphics library
import matplotlib.pyplot as plt

# %%
# SETTINGS

# Window size or the sequence length, 7 (1 week)
N_STEPS = 7

# Lookup steps, 1 is the next day, 3 = day after tomorrow
LOOKUP_STEPS = [1, 2, 3]

# The tech stocks we'll use for this analysis
STOCK = input('Enter a ticker. ')
print(f'You entered {STOCK}.')

# Current date
date_now = tm.strftime('%Y-%m-%d')
date_4_years_back = (dt.date.today() - dt.timedelta(days=1460)).strftime('%Y-%m-%d')
# Out:
# Enter a ticker. META
# You entered META.

# %%
# LOAD DATA
# from yahoo_fin
# for 1104 bars with interval = 1d (one day)
init_df = yf.get_data(
    STOCK,
    start_date=date_4_years_back,
    end_date=date_now,
    interval='1d')

# %%
# create the column 'date' based on index column
init_df['Date'] = init_df.index

# %%
# Let's preliminary see our data on the graphic
plt.style.use(style='ggplot')
plt.figure(figsize=(16,10))
plt.plot(init_df['close'][-200:])
plt.xlabel("days")
plt.ylabel("price")
plt.legend([f'Actual price for {STOCK}'])
plt.show()

# %%
# Scale data for ML engine
scaler = MinMaxScaler()
init_df['scaled_close'] = scaler.fit_transform(np.expand_dims(init_df['close'].values, axis=1))
display(init_df)
# Out:
#                   open        high         low       close    adjclose  \
# 2019-12-16  195.270004  199.119995  194.809998  197.919998  197.919998
# 2019-12-17  198.839996  199.000000  196.130005  198.389999  198.389999
# 2019-12-18  200.089996  204.300003  200.089996  202.500000  202.500000
# 2019-12-19  202.779999  206.300003  202.509995  206.059998  206.059998
# 2019-12-20  207.479996  207.710007  203.429993  206.300003  206.300003
# ...                ...         ...         ...         ...         ...
# 2023-12-06  321.929993  322.250000  317.040009  317.450012  317.450012
# 2023-12-07  317.769989  328.239990  317.769989  326.589996  326.589996
# 2023-12-08  323.089996  333.170013  323.000000  332.750000  332.750000
# 2023-12-11  329.399994  329.890015  320.000000  325.279999  325.279999
# 2023-12-12  324.600006  334.470001  324.559998  334.220001  334.220001
#
#               volume ticker       Date  scaled_close
# 2019-12-16  14911500   META 2019-12-16      0.371705
# 2019-12-17  10175700   META 2019-12-17      0.373308
# 2019-12-18  23274400   META 2019-12-18      0.387322
# 2019-12-19  16514600   META 2019-12-19      0.399461
# 2019-12-20  27306900   META 2019-12-20      0.400280
# ...              ...    ...        ...           ...
# 2023-12-06  11294300   META 2023-12-06      0.779282
# 2023-12-07  15905100   META 2023-12-07      0.810448
# 2023-12-08  14077500   META 2023-12-08      0.831452
# 2023-12-11  25802500   META 2023-12-11      0.805981
# 2023-12-12  18462500   META 2023-12-12      0.836465
#
# [1005 rows x 9 columns]

# %%
# create the column 'date' based on index column
init_df['date'] = init_df.index

# %%
def PrepareData(days):
  df = init_df.copy()
  df['future'] = df['scaled_close'].shift(-days)
  last_sequence = np.array(df[['scaled_close']].tail(days))
  df.dropna(inplace=True)
  sequence_data = []
  sequences = deque(maxlen=N_STEPS)

  for entry, target in zip(df[['scaled_close'] + ['Date']].values, df['future'].values):
      sequences.append(entry)
      if len(sequences) == N_STEPS:
          sequence_data.append([np.array(sequences), target])

  last_sequence = list([s[:len(['scaled_close'])] for s in sequences]) + list(last_sequence)
  last_sequence = np.array(last_sequence).astype(np.float32)

  # construct the X's and Y's
  X, Y = [], []
  for seq, target in sequence_data:
      X.append(seq)
      Y.append(target)

  # convert to numpy arrays
  X = np.array(X)
  Y = np.array(Y)

  return df, last_sequence, X, Y

# %%
def GetTrainedModel(x_train, y_train):
  model = Sequential()
  model.add(LSTM(60, return_sequences=True, input_shape=(N_STEPS, len(['scaled_close']))))
  model.add(Dropout(0.3))
  model.add(LSTM(120, return_sequences=False))
  model.add(Dropout(0.3))
  model.add(Dense(20))
  model.add(Dense(1))

  BATCH_SIZE = 128
  EPOCHS = 50

  model.compile(loss='mean_squared_error', optimizer='adam')

  model.fit(x_train, y_train,
            batch_size=BATCH_SIZE,
            epochs=EPOCHS,
            verbose=1)

  model.summary()

  return model

# %%
# GET PREDICTIONS
predictions = []

for step in LOOKUP_STEPS:
  df, last_sequence, x_train, y_train = PrepareData(step)
  x_train = x_train[:, :, :len(['scaled_close'])].astype(np.float32)

  model = GetTrainedModel(x_train, y_train)

  last_sequence = last_sequence[-N_STEPS:]
  last_sequence = np.expand_dims(last_sequence, axis=0)
  prediction = model.predict(last_sequence)
  predicted_price = scaler.inverse_transform(prediction)[0][0]

  predictions.append(round(float(predicted_price), 2))
# Out:
# Epoch 1/50
# 8/8 [==============================] - 5s 30ms/step - loss: 0.1492
# Epoch 2/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0306
# Epoch 3/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0195
# Epoch 4/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0107
# Epoch 5/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0089
# Epoch 6/50
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0072
# Epoch 7/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0060
# Epoch 8/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0047
# Epoch 9/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0048
# Epoch 10/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0047
# Epoch 11/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0041
# Epoch 12/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0044
# Epoch 13/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0042
# Epoch 14/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0039
# Epoch 15/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0038
# Epoch 16/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0040
# Epoch 17/50
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0037
# Epoch 18/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0037
# Epoch 19/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0038
# Epoch 20/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0036
# Epoch 21/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0036
# Epoch 22/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0035
# Epoch 23/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0036
# Epoch 24/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0036
# Epoch 25/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0033
# Epoch 26/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0034
# Epoch 27/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0036
# Epoch 28/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0031
# Epoch 29/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0033
# Epoch 30/50
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0032
# Epoch 31/50
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0029
# Epoch 32/50
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0029
# Epoch 33/50
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0032
# Epoch 34/50
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0032
# Epoch 35/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0032
# Epoch 36/50
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0031
# Epoch 37/50
# 8/8 [==============================] - 0s 54ms/step - loss: 0.0030
# Epoch 38/50
# 8/8 [==============================] - 0s 49ms/step - loss: 0.0028
# Epoch 39/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0030
# Epoch 40/50
# 8/8 [==============================] - 0s 48ms/step - loss: 0.0027
# Epoch 41/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0031
# Epoch 42/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0030
# Epoch 43/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0028
# Epoch 44/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0027
# Epoch 45/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0029
# Epoch 46/50
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0028
# Epoch 47/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0027
# Epoch 48/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0026
# Epoch 49/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0027
# Epoch 50/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0030
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 7, 60)             14880
#
#  dropout_6 (Dropout)         (None, 7, 60)             0
#
#  lstm_7 (LSTM)               (None, 120)               86880
#
#  dropout_7 (Dropout)         (None, 120)               0
#
#  dense_6 (Dense)             (None, 20)                2420
#
#  dense_7 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 104201 (407.04 KB)
# Trainable params: 104201 (407.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 1/1 [==============================] - 1s 776ms/step
# Epoch 1/50
# 8/8 [==============================] - 6s 34ms/step - loss: 0.1109
# Epoch 2/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0274
# Epoch 3/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0187
# Epoch 4/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0099
# Epoch 5/50
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0077
# Epoch 6/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0066
# Epoch 7/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0056
# Epoch 8/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0052
# Epoch 9/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0049
# Epoch 10/50
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0049
# Epoch 11/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0044
# Epoch 12/50
# 8/8 [==============================] - 0s 38ms/step - loss: 0.0045
# Epoch 13/50
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0043
# Epoch 14/50
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0044
# Epoch 15/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0040
# Epoch 16/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0044
# Epoch 17/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0042
# Epoch 18/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0041
# Epoch 19/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0040
# Epoch 20/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0041
# Epoch 21/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0040
# Epoch 22/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0041
# Epoch 23/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0042
# Epoch 24/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0036
# Epoch 25/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0039
# Epoch 26/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0036
# Epoch 27/50
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0034
# Epoch 28/50
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0035
# Epoch 29/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0037
# Epoch 30/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0037
# Epoch 31/50
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0039
# Epoch 32/50
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0035
# Epoch 33/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0034
# Epoch 34/50
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0035
# Epoch 35/50
# 8/8 [==============================] - 0s 54ms/step - loss: 0.0034
# Epoch 36/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0033
# Epoch 37/50
# 8/8 [==============================] - 0s 56ms/step - loss: 0.0037
# Epoch 38/50
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0035
# Epoch 39/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0034
# Epoch 40/50
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0033
# Epoch 41/50
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0034
# Epoch 42/50
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0035
# Epoch 43/50
# 8/8 [==============================] - 0s 53ms/step - loss: 0.0036
# Epoch 44/50
# 8/8 [==============================] - 0s 39ms/step - loss: 0.0034
# Epoch 45/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0034
# Epoch 46/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0036
# Epoch 47/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0036
# Epoch 48/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0032
# Epoch 49/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0033
# Epoch 50/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0032
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 7, 60)             14880
#
#  dropout_8 (Dropout)         (None, 7, 60)             0
#
#  lstm_9 (LSTM)               (None, 120)               86880
#
#  dropout_9 (Dropout)         (None, 120)               0
#
#  dense_8 (Dense)             (None, 20)                2420
#
#  dense_9 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 104201 (407.04 KB)
# Trainable params: 104201 (407.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 1/1 [==============================] - 1s 780ms/step
# Epoch 1/50
# 8/8 [==============================] - 6s 59ms/step - loss: 0.1505
# Epoch 2/50
# 8/8 [==============================] - 0s 56ms/step - loss: 0.0327
# Epoch 3/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0224
# Epoch 4/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0110
# Epoch 5/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0090
# Epoch 6/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0081
# Epoch 7/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0065
# Epoch 8/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0063
# Epoch 9/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0055
# Epoch 10/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0049
# Epoch 11/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0052
# Epoch 12/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0053
# Epoch 13/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0048
# Epoch 14/50
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0049
# Epoch 15/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0047
# Epoch 16/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0046
# Epoch 17/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0046
# Epoch 18/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0044
# Epoch 19/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0046
# Epoch 20/50
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0042
# Epoch 21/50
# 8/8 [==============================] - 0s 30ms/step - loss: 0.0046
# Epoch 22/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0042
# Epoch 23/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0040
# Epoch 24/50
# 8/8 [==============================] - 0s 36ms/step - loss: 0.0042
# Epoch 25/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0045
# Epoch 26/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0039
# Epoch 27/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0042
# Epoch 28/50
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0037
# Epoch 29/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0038
# Epoch 30/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0036
# Epoch 31/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0036
# Epoch 32/50
# 8/8 [==============================] - 0s 34ms/step - loss: 0.0038
# Epoch 33/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0037
# Epoch 34/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0039
# Epoch 35/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0037
# Epoch 36/50
# 8/8 [==============================] - 0s 32ms/step - loss: 0.0037
# Epoch 37/50
# 8/8 [==============================] - 0s 31ms/step - loss: 0.0039
# Epoch 38/50
# 8/8 [==============================] - 0s 29ms/step - loss: 0.0038
# Epoch 39/50
# 8/8 [==============================] - 0s 35ms/step - loss: 0.0037
# Epoch 40/50
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0036
# Epoch 41/50
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0037
# Epoch 42/50
# 8/8 [==============================] - 0s 62ms/step - loss: 0.0036
# Epoch 43/50
# 8/8 [==============================] - 0s 57ms/step - loss: 0.0038
# Epoch 44/50
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0036
# Epoch 45/50
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0040
# Epoch 46/50
# 8/8 [==============================] - 0s 60ms/step - loss: 0.0039
# Epoch 47/50
# 8/8 [==============================] - 0s 58ms/step - loss: 0.0035
# Epoch 48/50
# 8/8 [==============================] - 0s 55ms/step - loss: 0.0034
# Epoch 49/50
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0032
# Epoch 50/50
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0032
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 7, 60)             14880
#
#  dropout_10 (Dropout)        (None, 7, 60)             0
#
#  lstm_11 (LSTM)              (None, 120)               86880
#
#  dropout_11 (Dropout)        (None, 120)               0
#
#  dense_10 (Dense)            (None, 20)                2420
#
#  dense_11 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 104201 (407.04 KB)
# Trainable params: 104201 (407.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 1/1 [==============================] - 1s 743ms/step

# %%
# Execute model for the whole history range
copy_df = init_df.copy()
y_predicted = model.predict(x_train)
y_predicted_transformed = np.squeeze(scaler.inverse_transform(y_predicted))
first_seq = scaler.inverse_transform(np.expand_dims(y_train[:6], axis=1))
last_seq = scaler.inverse_transform(np.expand_dims(y_train[-3:], axis=1))
y_predicted_transformed = np.append(first_seq, y_predicted_transformed)
y_predicted_transformed = np.append(y_predicted_transformed, last_seq)
copy_df[f'predicted_close'] = y_predicted_transformed

# Add predicted results to the table
date_now = dt.date.today()
date_tomorrow = dt.date.today() + dt.timedelta(days=1)
date_after_tomorrow = dt.date.today() + dt.timedelta(days=2)

date_now = [predictions[0], f'{date_now}', 0, 0]
date_tomorrow = [predictions[1], f'{date_tomorrow}', 0, 0]
date_after_tomorrow = [predictions[2], f'{date_after_tomorrow}', 0, 0]
# Out:
# 32/32 [==============================] - 0s 8ms/step

# %%
# Result chart
plt.style.use(style='ggplot')
plt.figure(figsize=(16,10))
plt.plot(copy_df['close'][-150:].head(147))
plt.plot(copy_df['predicted_close'][-150:].head(147), linewidth=1, linestyle='dashed')
plt.plot(copy_df['close'][-150:].tail(4))
plt.xlabel('days')
plt.ylabel('price')
plt.legend([f'Actual price for {STOCK}',
            f'Predicted price for {STOCK}',
            f'Predicted price for future 3 days'])
plt.show()

# %%
if bool(predictions) == True and len(predictions) > 0:
  predictions_list = ['$' + str(d) for d in predictions]
  predictions_str = ', '.join(predictions_list)
  message = f'{STOCK} prediction for upcoming 3 days ({predictions_str})'

  print(message)
# Out:
# META prediction for upcoming 3 days ($323.08, $323.6, $321.54)
